# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
dt = pd.read_csv('./citrus.csv')
dt.head(5)
# Out:
#      name  diameter  weight  red  green  blue
# 0  orange      2.96   86.76  172     85     2
# 1  orange      3.91   88.05  166     78     3
# 2  orange      4.42   95.17  156     81     2
# 3  orange      4.47   95.60  163     81     4
# 4  orange      4.48   95.76  161     72     9

# %% [markdown]
# # Description
# ### This dataset takes the color, weight, and diameter of an "average" orange and generates a larger dataset containing a wide variety of values.

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5000 non-null   object
#  1   diameter  5000 non-null   float64
#  2   weight    5000 non-null   float64
#  3   red       5000 non-null   int64
#  4   green     5000 non-null   int64
#  5   blue      5000 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 234.5+ KB

# %%
dt.shape
# Out:
# (5000, 6)

# %%
dt.describe()
# Out:
#           diameter       weight          red        green         blue
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      8.474424   152.804920   156.832800    81.988200     7.115200
# std       1.260665    18.669021     9.890258    10.090789     6.493779
# min       2.960000    86.760000   123.000000    49.000000     2.000000
# 25%       7.650000   140.147500   150.000000    75.000000     2.000000
# 50%       8.470000   152.665000   157.000000    82.000000     4.000000
# 75%       9.300000   165.430000   163.000000    89.000000    11.000000
# max      12.870000   231.090000   192.000000   116.000000    38.000000

# %%
orange_dt=dt.sample(30) #because i have alot of data rows so i choose 30 random from it
orange_dt
X = orange_dt['diameter'].values
y = orange_dt['weight'].values

# %%
X=X.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X , y , test_size = 0.25, random_state = 4 )

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Regression Model’s Score

# %%
accu = model.score(X_test , y_test)
accu*100
# Out:
# 99.86352791224465

# %%
y_predict = model.predict(X_test)

# %% [markdown]
# # Conclusions

# %%
plt.scatter(X_train, y_train)
plt.plot(X_test, y_predict , color = 'orange')
plt.xlabel('Diameter (cm)')
plt.ylabel('Weight (g)')
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_predict , color = 'orange')
plt.xlabel('Diameter (cm)')
plt.ylabel('Weight (g)')
plt.show()

# %%
orange_diameter = 7
orange_weight = model.predict([[orange_diameter]])[0]
print(f'If the diameter of orange = {orange_diameter} cm. The weight for the orange = {orange_weight} g. ')
# Out:
# If the diameter of orange = 7 cm. The weight for the orange = 130.94734989644422 g.
